# %% [markdown]
# # [作業目標]
# - 使用 Day 12 剛學到的方法, 對較完整的資料生成離散化特徵
# - 觀察上述離散化特徵, 對於目標值的預測有沒有幫助

# %% [markdown]
# # [作業重點]
# - 仿照 Day 12 的語法, 將年齡資料 ('DAYS_BIRTH' 除以 365) 離散化
# - 繪製上述的 "離散化標籤" 與目標值 ('TARGET') 的長條圖

# %%
# 載入需要的套件
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# 設定 data_path
dir_data = ''

# %% [markdown]
# ### 之前做過的處理

# %%
# 讀取資料檔
f_app_train = os.path.join(dir_data, 'application_train.csv')
app_train = pd.read_csv(f_app_train)
app_train.shape
# Out:
# (307511, 122)

# %%
# 將只有兩種值的類別型欄位, 做 Label Encoder, 計算相關係數時讓這些欄位可以被包含在內
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# 檢查每一個 column
for col in app_train:
    if app_train[col].dtype == 'object':
        # 如果只有兩種值的類別型欄位
        if len(list(app_train[col].unique())) <= 2:
            # 就做 Label Encoder, 以加入相關係數檢查
            app_train[col] = le.fit_transform(app_train[col])            
print(app_train.shape)
app_train.head()
# Out:
# (307511, 122)
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE CODE_GENDER  FLAG_OWN_CAR  \
# 0      100002       1                   0           M             0
# 1      100003       0                   0           F             0
# 2      100004       0                   1           M             1
# 3      100006       0                   0           F             0
# 4      100007       0                   0           M             0
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                1             0          202500.0    406597.5      24700.5
# 1                0             0          270000.0   1293502.5      35698.5
# 2                1             0           67500.0    135000.0       6750.0
# 3                1             0          135000.0    312682.5      29686.5
# 4                1             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
# 受雇日數為異常值的資料, 另外設一個欄位記錄, 並將異常的日數轉成空值 (np.nan)
app_train['DAYS_EMPLOYED_ANOM'] = app_train["DAYS_EMPLOYED"] == 365243
app_train['DAYS_EMPLOYED'].replace({365243: np.nan}, inplace = True)

# 出生日數 (DAYS_BIRTH) 取絕對值 
app_train['DAYS_BIRTH'] = abs(app_train['DAYS_BIRTH'])

# %%
app_train.head()
# Out:
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE CODE_GENDER  FLAG_OWN_CAR  \
# 0      100002       1                   0           M             0
# 1      100003       0                   0           F             0
# 2      100004       0                   1           M             1
# 3      100006       0                   0           F             0
# 4      100007       0                   0           M             0
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                1             0          202500.0    406597.5      24700.5
# 1                0             0          270000.0   1293502.5      35698.5
# 2                1             0           67500.0    135000.0       6750.0
# 3                1             0          135000.0    312682.5      29686.5
# 4                1             0          121500.0    513000.0      21865.5
#
#           ...          FLAG_DOCUMENT_19 FLAG_DOCUMENT_20 FLAG_DOCUMENT_21  \
# ...

# %% [markdown]
# ## 練習時間
# 參考 Day 12 範例程式，離散化你覺得有興趣的欄位，並嘗試找出有趣的訊息

# %%
app_train['YEAR_BIRTH_GROUP'] =pd.cut(app_train["DAYS_BIRTH"]/365, [20,30,40,50,100])

# %%
print("Correlation between TARGET and DAYS_BIRTH", app_train['DAYS_BIRTH'].corr(app_train['TARGET']))
(app_train['DAYS_BIRTH']/365).describe()
# Out:
# Correlation between TARGET and DAYS_BIRTH -0.0782393083098
# count    307511.000000
# mean         43.936973
# std          11.956133
# min          20.517808
# 25%          34.008219
# 50%          43.150685
# 75%          53.923288
# max          69.120548
# Name: DAYS_BIRTH, dtype: float64

# %%
#最大:69，最小:20 切10個區塊
app_train['YEAR_BIRTH_GROUP'] = pd.cut(app_train["DAYS_BIRTH"]/365, bins = np.linspace(20, 70, num = 11))
app_train.head(10)
# Out:
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE CODE_GENDER  FLAG_OWN_CAR  \
# 0      100002       1                   0           M             0
# 1      100003       0                   0           F             0
# 2      100004       0                   1           M             1
# 3      100006       0                   0           F             0
# 4      100007       0                   0           M             0
# 5      100008       0                   0           M             0
# 6      100009       0                   0           F             1
# 7      100010       0                   0           M             1
# 8      100011       0                   0           F             0
# 9      100012       0                   1           M             0
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                1             0          202500.0    406597.5      24700.5
# ...

# %%
app_train['YEAR_BIRTH_GROUP'].value_counts().sort_index()
# Out:
# (20.0, 25.0]    12159
# (25.0, 30.0]    32862
# (30.0, 35.0]    39440
# (35.0, 40.0]    42868
# (40.0, 45.0]    41406
# (45.0, 50.0]    35135
# (50.0, 55.0]    34942
# (55.0, 60.0]    33120
# (60.0, 65.0]    27476
# (65.0, 70.0]     8103
# Name: YEAR_BIRTH_GROUP, dtype: int64

# %%
#每一組的平均值
group=c.groupby('YEAR_BIRTH_GROUP').mean()

# %%
group
# Out:
#                      SK_ID_CURR    TARGET  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  \
# YEAR_BIRTH_GROUP
# (20.0, 25.0]      277358.960688  0.123036            0.262604      0.318283
# (25.0, 30.0]      277837.106628  0.111436            0.107084      0.382265
# (30.0, 35.0]      277962.566709  0.102814            0.098301      0.409432
# (35.0, 40.0]      278149.565527  0.089414            0.095269      0.405734
# (40.0, 45.0]      278885.543375  0.078491            0.095349      0.392093
# (45.0, 50.0]      277999.882226  0.074171            0.089796      0.357535
# (50.0, 55.0]      278391.825883  0.066968            0.081707      0.310486
# (55.0, 60.0]      278547.738647  0.055314            0.078865      0.253623
# (60.0, 65.0]      277842.816858  0.052737            0.073701      0.197008
# (65.0, 70.0]      277944.150315  0.037270            0.001358      0.142540
#
#                   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# YEAR_BIRTH_GROUP
# ...

# %%
plt.bar(range(len(group.index)),  group['TARGET'])
plt.xticks(range(len(group.index)),group.index,rotation=30)
#越年輕的客戶族群的違約遲繳的可能越大！
# Out:
# ([<matplotlib.axis.XTick at 0xc772390>,
# ...
#  <a list of 10 Text xticklabel objects>)

# %%
plt_column = ['AMT_INCOME_TOTAL']
plt_by =['YEAR_BIRTH_GROUP']
app_train
.boxplot(column=plt_column, by = plt_by, showfliers = False, figsize=(12,12))
#plt.xticks(rotation=30)
plt.show()
